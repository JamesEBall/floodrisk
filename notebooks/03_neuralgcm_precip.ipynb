# %% [markdown]
# # 03 — NeuralGCM Precipitation Forecasts
#
# Generate precipitation forecasts using NeuralGCM and regrid to catchment-mean values.
#
# **Prerequisite**: Install the `neuralgcm` extra: `pip install -e .[neuralgcm]`

# %%
from floodrisk.neuralgcm_bridge.forecast import NeuralGCMForecaster
from floodrisk.neuralgcm_bridge.regrid import regrid_to_catchment
from floodrisk.neuralgcm_bridge.cache import CacheManager

# Initialize forecaster (requires neuralgcm checkpoint)
# forecaster = NeuralGCMForecaster(checkpoint_path="path/to/checkpoint")
print("NeuralGCM bridge modules loaded successfully")

# %%
# Run a forecast (uncomment when checkpoint is available)
# ds = forecaster.run_forecast(init_time="2020-01-01", duration_hours=240)
# print(ds)

# %%
# Regrid to catchment means (uncomment when forecast data is available)
# catchment_bounds = {
#     "01013500": {"lat_min": 46.5, "lat_max": 47.5, "lon_min": -69.5, "lon_max": -68.5},
# }
# precip_catchment = regrid_to_catchment(ds["precipitation"], catchment_bounds)
# print(precip_catchment.head())

# %%
# Cache management
cache = CacheManager(cache_dir="../cache/neuralgcm")
print(f"Cached forecasts: {cache.list_forecasts()}")
