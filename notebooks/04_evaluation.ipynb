# %% [markdown]
# # 04 — Model Evaluation
#
# Evaluate a trained streamflow model: per-basin NSE/KGE, hydrographs, and spatial maps.

# %%
import torch
from floodrisk.config import ExperimentConfig
from floodrisk.models import build_model

cfg = ExperimentConfig.from_yaml("../configs/streamflow/lstm_camels.yaml")

# Load trained model
# checkpoint = torch.load("checkpoints/best.pt")
# model = build_model(cfg.model.type, n_features=..., hidden_size=cfg.model.hidden_size)
# model.load_state_dict(checkpoint["model_state_dict"])
print("Model loaded (uncomment above when checkpoint is available)")

# %%
# Run evaluation pipeline
# from floodrisk.evaluation.evaluate import EvaluationPipeline
# pipeline = EvaluationPipeline(model, test_dataset)
# results = pipeline.run()
# summary = pipeline.summary(results)
# print(f"Median NSE: {summary['nse_median']:.3f}")

# %%
# Generate plots
# from floodrisk.evaluation.plots import plot_hydrograph, plot_nse_cdf, plot_nse_map
# plot_hydrograph(observed, predicted, basin_id="01013500")
# plot_nse_cdf(list(results.values()))
# plot_nse_map(results)
